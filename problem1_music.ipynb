# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
df_labels_train = pd.read_csv('music_train_labels.csv')
column_names=[i for i in range(0,550)]

# %%
df_features=pd.read_csv('df_train_anon.csv',header=None)

# %%
Y=df_features[549]
y=Y.tolist()

# %%
M=df_features.to_dict()

# %%
X=[]
for j in range(0,len(M[1])):
    l=[]
    for i in range(0,549):
        l.append(M[i][j])
    X.append(l)

# %%
scaler = preprocessing.StandardScaler()

# %%
scaler.scale_ = scaler.scale.copy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-c9a2a8a7ef97> in <module>()
# ----> 1 scaler.scale_ = scaler.scale.copy()
#
# AttributeError: 'StandardScaler' object has no attribute 'scale'

# %%
from sklearn import preprocessing
from sklearn.decomposition import PCA
import scipy as sp
import sklearn as sk
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split

class Estimator_prob1(sk.base.BaseEstimator, sk.base.RegressorMixin):
    """
    A shell estimator that combines a transformer and regressor into a single object.
    """
    def __init__(self, transformer, model):
        self.transformer = transformer
        self.model = model
        pass

    def fit(self, X, y):
        X_trans = self.transformer.fit(X)
        self.model.fit(X_trans, y)
        self.model.scale_=self.model.scale_.copy()
        return self
    
    def score(self, X, y):
        X_test = self.transformer.transform(X)
        return self.model.score(X_test, y)

    def predict(self, X):
        X_test = self.transformer.transform(X)
        X_test=X_test.reshape(1, -1)
        return self.model.predict(X_test)
    
class Transformer_prob1(sk.base.BaseEstimator, sk.base.TransformerMixin):
    """
    Returns the first k columns of a feature array
    """
    def __init__(self):
        self.model= preprocessing.StandardScaler()
        self.pca= PCA(n_components=500)

    def fit(self, X):
        scaler=self.model.fit_transform(X)
        l=[]
        self.model.scale_=self.model.scale_.copy()
        for row in scaler:
            l.append(row)
        return self.pca.fit_transform(l)
        
        
    def transform(self, X):
        #X1=self.filter1(X)
        input1=self.model.transform(X)
        l=[]
        for row in input1:
            l.append(row)
        k=self.pca.transform(l)    
        return k

# %%
from sklearn import preprocessing
from sklearn.decomposition import PCA


import scipy as sp
import sklearn as sk
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split

class Estimator_prob1(sk.base.BaseEstimator, sk.base.RegressorMixin):
    """
    A shell estimator that combines a transformer and regressor into a single object.
    """
    def __init__(self, transformer, model):
        self.transformer = transformer
        self.model = model
        pass

    def fit(self, X, y):
        X_trans = self.transformer.fit(X)
        self.model.fit(X_trans, y)
        
        return self
    
    def score(self, X, y):
        X_test = self.transformer.transform(X)
        return self.model.score(X_test, y)

    def predict(self, X):
        X_test = self.transformer.transform(X)
        X_test=X_test.reshape(1, -1)
        return self.model.predict(X_test)
    
class Transformer_prob1(sk.base.BaseEstimator, sk.base.TransformerMixin):
    """
    Returns the first k columns of a feature array
    """
    def __init__(self):
        self.model= preprocessing.StandardScaler()
        self.pca= PCA(n_components=400)

    def fit(self, X):
        scaler=self.model.fit_transform(X)
        l=[]
        self.model.scale_=self.model.std_.copy()
        for row in scaler:
            l.append(row)
        return self.pca.fit_transform(l)
        
        
    def transform(self, X):
        #X1=self.filter1(X)
        input1=self.model.transform(X)
        l=[]
        for row in input1:
            l.append(row)
        k=self.pca.transform(l)    
        return k

# %%
X1=[1,2,3,1,2,3,4]

k=np.array(X1).reshape(1,-1)
k[0][1]
# Out:
# 2

# %%
t=Transformer_prob1()

# %%
t.fit(X)
# Out:
# /Users/sevenseasjim/anaconda2/lib/python2.7/site-packages/sklearn/utils/__init__.py:93: DeprecationWarning: Function std_ is deprecated; Attribute ``std_`` will be removed in 0.19. Use ``scale_`` instead
#   warnings.warn(msg, category=DeprecationWarning)
# array([[ -1.73130552e+01,   2.48576635e+00,   2.29553618e+01, ...,
#           1.89170510e-02,   1.40388161e-02,   1.61113030e-02],
#        [  6.89173536e+00,  -1.27309994e+01,   4.42397955e+00, ...,
#           1.96386951e-01,  -2.87282317e-02,  -1.15756745e-01],
#        [ -1.42069900e+01,  -5.51300059e+00,   1.21062928e+01, ...,
#          -2.51446700e-02,  -3.14927746e-02,  -1.41132271e-02],
#        ...,
#        [  1.86178661e+01,   8.70974481e+00,  -2.58481396e+00, ...,
#           1.81260821e-01,   5.99351511e-02,   1.23192963e-01],
#        [  3.21411110e+00,   8.45316482e+00,  -1.61097767e+01, ...,
#           4.63319788e-02,   2.47372097e-02,  -5.12758441e-02],
#        [  2.21502656e+00,   8.80264747e+00,   5.96057352e+00, ...,
#          -3.07069438e-03,   6.23220984e-02,  -3.34028702e-02]])

# %%
t.transform(X[1])
# Out:
# /Users/sevenseasjim/anaconda2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:646: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/sevenseasjim/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# array([[  6.89173536e+00,  -1.27309994e+01,   4.42397955e+00,
#          -1.67898264e+01,   1.20920126e+01,  -1.41324557e+01,
#          -3.99675038e+00,  -3.99593294e+00,  -4.49175365e+00,
#           8.89709213e-01,   3.96018524e-01,  -6.02065382e+00,
#           9.22328945e-01,  -2.52348711e+00,  -1.45611375e+00,
#           4.63094717e-01,   1.06423520e+00,   7.78277573e-01,
#           1.97517896e+00,   5.83918802e-01,  -1.03177244e+00,
#           2.69249060e-01,  -2.23575558e-01,   2.68732846e+00,
#          -1.97394572e+00,   5.40442254e-01,  -3.60890746e-01,
#           4.18456869e-01,   1.93234364e+00,   1.48114706e+00,
#          -6.06513185e-01,   1.83542926e+00,   1.54765755e-02,
#           2.41115756e+00,   4.28693443e+00,   3.69366883e-01,
#          -2.06830292e+00,  -9.96723817e-01,  -1.23809334e+00,
#           9.69720504e-01,  -2.47962763e+00,  -8.32427422e-01,
#          -9.18510794e-01,  -2.47280244e-02,  -2.94239550e-01,
#           3.13167522e+00,   3.58877183e-01,   3.72162454e+00,
#          -8.48830374e-01,   1.26107523e-01,   4.42091457e-01,
#           1.08058469e+00,   1.98573390e+00,   7.70406395e-01,
#          -7.26633879e-02,   1.35301314e+00,   1.23381698e+00,
#          -1.01330272e+00,   1.44810693e-01,  -7.19538919e-01,
#          -1.65513065e+00,   2.44364530e-01,  -1.42606382e+00,
#           1.36281220e+00,  -1.55803453e+00,   6.94587712e-01,
#           1.21496003e+00,   1.33274762e+00,   1.50002016e+00,
#           2.13910864e+00,  -6.03294953e-02,  -7.83853542e-01,
#           8.95216918e-03,   6.04441657e-01,   1.13743587e+00,
#           6.30664506e-02,   1.05935782e-01,   7.38355181e-02,
#          -1.41595446e-02,   1.63858721e-01,  -1.98572528e-01,
#          -1.77176786e-01,   1.94977558e-02,   1.06679418e-01,
#           6.26819948e-02,   7.42812949e-02,  -4.71526830e-02,
#          -2.82579918e-02,   1.25280732e-01,  -1.14431208e-01,
#           1.04263329e-02,   9.36697499e-02,   1.31659899e-01,
#          -2.20800188e-02,  -8.07334978e-02,   3.79249973e-02,
#           1.83557411e-01,   7.81752938e-02,   6.49218435e-02,
#          -1.63292632e-01,   1.62267736e-02,   1.11955011e-02,
#           1.01854762e-01,   1.51008344e-01,   4.00945369e-02,
#           2.13561278e-03,   7.27266988e-02,   5.20144434e-02,
#          -1.17836689e-01,  -1.88806164e-02,  -3.36588204e-02,
#           1.24833618e-01,  -5.44966177e-02,  -8.94861444e-02,
#          -2.98588669e-02,   1.70962458e-02,  -7.29408059e-02,
#          -1.37870049e-02,   4.76081341e-02,   1.63177208e-02,
#          -6.43373737e-02,   4.24894485e-02,   6.17952925e-02,
#           1.46587332e-01,   1.96386951e-01,  -2.87282317e-02,
#          -1.15756745e-01]])

# %%
PCA(copy=True, n_components='mle', whiten=False)
# Out:
# PCA(copy=True, n_components='mle', whiten=False)

# %%
# Out:
# 548

# %%
from sklearn import svm

# %%
shell1 = Estimator_prob1(Transformer_prob1(),svm.SVC())

# %%
shell1.fit(X,y)
# Out:
# /Users/sevenseasjim/anaconda2/lib/python2.7/site-packages/sklearn/utils/__init__.py:93: DeprecationWarning: Function std_ is deprecated; Attribute ``std_`` will be removed in 0.19. Use ``scale_`` instead
#   warnings.warn(msg, category=DeprecationWarning)
# Estimator_prob1(model=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#         transformer=Transformer_prob1())

# %%
X[1]
# Out:
# [0.0090436220444059957,
#  0.00014052791310786102,
#  7.2537586145065518,
#  66.717845949091924,
#  0.005859375,
#  0.00244140625,
#  0.14794921875,
#  0.0086189552589699056,
#  6.774937688016601e-05,
#  3.2037437909367172,
#  21.627617228900245,
#  0.006795247395833333,
#  0.0033365885416666674,
#  0.05029296875,
#  2.5100562572479248,
#  2.6270437240600581,
#  0.13546448945999146,
#  -0.874847412109375,
#  2.5773258209228511,
#  9.5463838079012998e-05,
#  6.9700493812561044,
#  2.5178738037745156,
#  1.7211612065633135,
#  0.4520585909485817,
#  -0.49358169237772631,
#  2.1658689677715302,
#  0.48722022383784253,
#  5.8125002384185791,
#  728.36845192626708,
#  488228.63898391358,
#  5.1444722553132642,
#  55.693697830566727,
#  460.15863255902195,
#  210.80059979427452,
#  10794.773907008946,
#  713.85903454412266,
#  225902.35506136046,
#  1.8279638880348199,
#  5.5178468836754364,
#  652.71733674840789,
#  270.39909322558731,
#  2540.7742723946658,
#  1682.4204030648957,
#  609757.61833314504,
#  1.5534561857358364,
#  2.6539246053225067,
#  1371.0311758692792,
#  785.7531643792222,
#  6374.6783969861881,
#  1672.9915207160307,
#  365449.42535884329,
#  0.98786015831658602,
#  1.14874440279533,
#  -0.19794344443213821,
#  0.095601420560791142,
#  -1.1041252730890412,
#  -17.697219557969021,
#  13.311783271902794,
#  1.0,
#  0.8382930839452627,
#  0.67412776334033953,
#  0.6258803689229242,
#  0.61251664963115382,
#  0.61115806870340006,
#  0.62364801405937609,
#  0.64384637140981704,
#  0.64387289607092713,
#  0.61745612988257048,
#  0.60076608075297844,
#  0.59417602392155966,
#  0.59322909813968905,
#  0.59562978298455405,
#  0.60234828376606542,
#  0.6078766668266109,
#  0.60950380373426793,
#  0.61818756003270081,
#  0.61825019646291168,
#  0.61221877356845678,
#  0.612989074817055,
#  0.61240458334910175,
#  0.60864238259762848,
#  0.62420431946068511,
#  0.64004679293888267,
#  0.63709799475941875,
#  0.63833420093170012,
#  0.63538805754050154,
#  0.65043745707970557,
#  0.67266800293960993,
#  0.66918398783168154,
#  0.65367325632384266,
#  0.63811916472291341,
#  0.61984871094111915,
#  0.61526150395193746,
#  0.61334877551867695,
#  0.60750821582046566,
#  0.60426172881039675,
#  0.60421351175744176,
#  0.60422704755179013,
#  0.60656134776502169,
#  0.61301943207796927,
#  0.61745042944797801,
#  0.60480724764123739,
#  0.59065097534827316,
#  0.58954784500175184,
#  0.60052947155844238,
#  0.61563341521644488,
#  0.6105574409420762,
#  0.60272421583462121,
#  0.60710748427188999,
#  0.61059364423621842,
#  0.60375134387299645,
#  0.60728434181208224,
#  0.61644758173398806,
#  0.62117933692537042,
#  0.61352940140603396,
#  0.61594948927697957,
#  0.62945716877896973,
#  0.62325029035267276,
#  0.60157078182019685,
#  0.59607952169101408,
#  0.59963425434134265,
#  0.60742160174271942,
#  0.61195360057508208,
#  0.59421432601623458,
#  0.57493663014332985,
#  0.57267956953235077,
#  0.57755882048631579,
#  0.57637012835795598,
#  0.58463308284507487,
#  0.59886313335297281,
#  0.59893927131043245,
#  0.58803182519468888,
#  0.58588942071953665,
#  0.58388972288308361,
#  0.58613440223973734,
#  0.5893483689991762,
#  0.60624623518645382,
#  0.61930739887997632,
#  0.59442211631182273,
#  0.62335227714464048,
#  0.65632504380090761,
#  0.62669016233941133,
#  0.59048592377559961,
#  0.56513321368412761,
#  0.55543577305494496,
#  0.56696487242934823,
#  0.58701800204528098,
#  0.5902763983400201,
#  0.58745294581379059,
#  0.57640616071707251,
#  0.56145870426177613,
#  0.55148259714211345,
#  0.54479354156765758,
#  0.55213463986354927,
#  0.57674526986262165,
#  0.58195070947552519,
#  0.57804799749910085,
#  0.57841055464944646,
#  123.046875]

# %%
k=shell1.predict(X[1])
# Out:
# /Users/sevenseasjim/anaconda2/lib/python2.7/site-packages/sklearn/preprocessing/data.py:646: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /Users/sevenseasjim/anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)

# %%
k
# Out:
# array(['jazz'],
#       dtype='|S11')

# %%
y[0:10]
# Out:
# ['jazz',
#  'jazz',
#  'electronic',
#  'jazz',
#  'electronic',
#  'jazz',
#  'folkcountry',
#  'jazz',
#  'electronic',
#  'folkcountry']

# %%
import dill
dill.dump(shell, open("muzak1.dill", "w"))

# %%
import dill
dill.dump(t, open("pritesh_music_test.dill", "w"))
